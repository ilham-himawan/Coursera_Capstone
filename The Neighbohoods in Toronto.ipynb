# %% [markdown]
# # **Cluster The Neighborhoods in Toronto**

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
headers=["PostalCode","Borough","Neighborhood"]
df=pd.read_table(url, names=headers)

# %%
df.head()
# Out:
#                                           PostalCode Borough Neighborhood
# 0                                    <!DOCTYPE html>     NaN          NaN
# 1     <html class="client-nojs" lang="en" dir="ltr">     NaN          NaN
# 2                                             <head>     NaN          NaN
# 3                            <meta charset="UTF-8"/>     NaN          NaN
# 4  <title>List of postal codes of Canada: M - Wik...     NaN          NaN

# %%
df.shape
# Out:
# (1624, 3)

# %%
df.dropna(subset=["Borough"],axis=0)
# Out:
#      PostalCode                                            Borough  \
# 34          NaN                                   <a id="top"></a>
# 35          NaN  <div id="siteNotice" class="mw-body-content"><...
# 36          NaN        <div class="mw-indicators mw-body-content">
# 37          NaN                                             </div>
# 38          NaN  <h1 id="firstHeading" class="firstHeading" lan...
# 39          NaN     <div id="bodyContent" class="mw-body-content">
# 1453        NaN                                             </div>
# 1456        NaN            <div class="read-more-container"></div>
# 1459        NaN                           <h2>Navigation menu</h2>
# 1460        NaN                                 <div id="mw-head">
# 1463        NaN                                                  >
# 1464        NaN                         <h3 id="p-personal-label">
# 1466        NaN                                              </h3>
# 1467        NaN                  <div class="vector-menu-content">
# 1470        NaN                                             </div>
# 1475        NaN                                                  >
# 1476        NaN                       <h3 id="p-namespaces-label">
# 1478        NaN                                              </h3>
# 1479        NaN                  <div class="vector-menu-content">
# 1482        NaN                                             </div>
# 1486        NaN                                                  >
# 1487        NaN  <input type="checkbox" class="vector-menu-chec...
# 1488        NaN                         <h3 id="p-variants-label">
# 1490        NaN                                              </h3>
# 1491        NaN                  <div class="vector-menu-content">
# 1494        NaN                                             </div>
# 1500        NaN                                                  >
# 1501        NaN                            <h3 id="p-views-label">
# 1503        NaN                                              </h3>
# 1504        NaN                  <div class="vector-menu-content">
# 1507        NaN                                             </div>
# 1511        NaN                                                  >
# 1512        NaN  <input type="checkbox" class="vector-menu-chec...
# 1513        NaN                         <h3 id="p-cactions-label">
# 1515        NaN                                              </h3>
# 1516        NaN                  <div class="vector-menu-content">
# 1519        NaN                                             </div>
# 1522        NaN                                              <h3 >
# 1524        NaN                                              </h3>
# 1525        NaN       <form action="/w/index.php" id="searchform">
# 1532        NaN                                            </form>
# 1535        NaN                                             </div>
# 1538        NaN                    <div id="p-logo" role="banner">
# 1540        NaN                                             </div>
# 1541        NaN  <!-- Please do not use role attribute as CSS s...
# 1543        NaN                                                  >
# 1544        NaN                       <h3 id="p-navigation-label">
# 1546        NaN                                              </h3>
# 1547        NaN                  <div class="vector-menu-content">
# 1550        NaN                                             </div>
# 1552        NaN  <!-- Please do not use role attribute as CSS s...
# 1554        NaN                                                  >
# 1555        NaN                      <h3 id="p-interaction-label">
# 1557        NaN                                              </h3>
# 1558        NaN                  <div class="vector-menu-content">
# 1561        NaN                                             </div>
# 1565        NaN                                                  >
# 1566        NaN                               <h3 id="p-tb-label">
# 1568        NaN                                              </h3>
# 1569        NaN                  <div class="vector-menu-content">
# 1572        NaN                                             </div>
# 1576        NaN                                                  >
# 1577        NaN                <h3 id="p-coll-print_export-label">
# 1579        NaN                                              </h3>
# 1580        NaN                  <div class="vector-menu-content">
# 1583        NaN                                             </div>
# 1585        NaN  <!-- Please do not use role attribute as CSS s...
# 1587        NaN                                                  >
# 1588        NaN                             <h3 id="p-lang-label">
# 1590        NaN                                              </h3>
# 1591        NaN                  <div class="vector-menu-content">
# 1594        NaN                                             </div>
# 1599        NaN                             <ul id="footer-info" >
# 1600        NaN  <li id="footer-info-lastmod"> This page was la...
# 1601        NaN  <li id="footer-info-copyright">Text is availab...
# 1604        NaN                           <ul id="footer-places" >
# 1605        NaN  <li id="footer-places-privacy"><a href="https:...
# 1606        NaN  <li id="footer-places-about"><a href="/wiki/Wi...
# 1607        NaN  <li id="footer-places-disclaimer"><a href="/wi...
# 1608        NaN  <li id="footer-places-contact"><a href="//en.w...
# 1609        NaN  <li id="footer-places-mobileview"><a href="//e...
# 1610        NaN  <li id="footer-places-developers"><a href="htt...
# 1611        NaN  <li id="footer-places-statslink"><a href="http...
# 1612        NaN  <li id="footer-places-cookiestatement"><a href...
# 1614        NaN             <ul id="footer-icons" class="noprint">
# 1615        NaN  <li id="footer-copyrightico"><a href="https://...
# 1616        NaN  <li id="footer-poweredbyico"><a href="https://...
# 1618        NaN                   <div style="clear: both;"></div>
#
#      Neighborhood
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 1453          NaN
# 1456          NaN
# 1459          NaN
# 1460          NaN
# 1463          NaN
# 1464          NaN
# 1466          NaN
# 1467          NaN
# 1470          NaN
# 1475          NaN
# 1476          NaN
# 1478          NaN
# 1479          NaN
# 1482          NaN
# 1486          NaN
# 1487          NaN
# 1488          NaN
# 1490          NaN
# 1491          NaN
# 1494          NaN
# 1500          NaN
# 1501          NaN
# 1503          NaN
# 1504          NaN
# 1507          NaN
# 1511          NaN
# 1512          NaN
# 1513          NaN
# 1515          NaN
# 1516          NaN
# 1519          NaN
# 1522          NaN
# 1524          NaN
# 1525          NaN
# 1532          NaN
# 1535          NaN
# 1538          NaN
# 1540          NaN
# 1541          NaN
# 1543          NaN
# 1544          NaN
# 1546          NaN
# 1547          NaN
# 1550          NaN
# 1552          NaN
# 1554          NaN
# 1555          NaN
# 1557          NaN
# 1558          NaN
# 1561          NaN
# 1565          NaN
# 1566          NaN
# 1568          NaN
# 1569          NaN
# 1572          NaN
# 1576          NaN
# 1577          NaN
# 1579          NaN
# 1580          NaN
# 1583          NaN
# 1585          NaN
# 1587          NaN
# 1588          NaN
# 1590          NaN
# 1591          NaN
# 1594          NaN
# 1599          NaN
# 1600          NaN
# 1601          NaN
# 1604          NaN
# 1605          NaN
# 1606          NaN
# 1607          NaN
# 1608          NaN
# 1609          NaN
# 1610          NaN
# 1611          NaN
# 1612          NaN
# 1614          NaN
# 1615          NaN
# 1616          NaN
# 1618          NaN

# %%
df.head()
# Out:
#                                           PostalCode Borough Neighborhood
# 0                                    <!DOCTYPE html>     NaN          NaN
# 1     <html class="client-nojs" lang="en" dir="ltr">     NaN          NaN
# 2                                             <head>     NaN          NaN
# 3                            <meta charset="UTF-8"/>     NaN          NaN
# 4  <title>List of postal codes of Canada: M - Wik...     NaN          NaN
